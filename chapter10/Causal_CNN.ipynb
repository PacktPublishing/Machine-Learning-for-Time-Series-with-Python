# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)

# %%
import numpy as np
import pandas as pd
from keras.layers import Conv1D, Input, Add, Activation, Dropout
from keras.models import Sequential, Model
from keras.layers.advanced_activations import LeakyReLU, ELU
from keras import optimizers
import tensorflow as tf

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)


def DC_CNN_Block(nb_filter, filter_length, dilation):
    def f(input_):
        residual =    input_
        layer_out =   Conv1D(
            filters=nb_filter, kernel_size=filter_length, 
            dilation_rate=dilation, 
            activation='linear', padding='causal', use_bias=False
        )(input_)                    
        layer_out =   Activation('selu')(layer_out)        
        skip_out =    Conv1D(1, 1, activation='linear', use_bias=False)(layer_out)        
        network_in =  Conv1D(1, 1, activation='linear', use_bias=False)(layer_out)                      
        network_out = Add()([residual, network_in])        
        return network_out, skip_out    
    return f


def DC_CNN_Model(length):
    input = Input(shape=(length,1))
    l1a, l1b = DC_CNN_Block(32, 2, 1)(input)    
    l2a, l2b = DC_CNN_Block(32, 2, 2)(l1a) 
    l3a, l3b = DC_CNN_Block(32, 2, 4)(l2a)
    l4a, l4b = DC_CNN_Block(32, 2, 8)(l3a)
    l5a, l5b = DC_CNN_Block(32, 2, 16)(l4a)
    l6a, l6b = DC_CNN_Block(32, 2, 32)(l5a)
    l6b = Dropout(0.8)(l6b)
    l7a, l7b = DC_CNN_Block(32, 2, 64)(l6a)
    l7b = Dropout(0.8)(l7b)
    l8 =   Add()([l1b, l2b, l3b, l4b, l5b, l6b, l7b])
    l9 =   Activation('relu')(l8)   
    l21 =  Conv1D(1, 1, activation='linear', use_bias=False)(l9)
    model = Model(inputs=input, outputs=l21)
    model.compile(loss='mae', optimizer=optimizers.adam_v2.Adam(), metrics=['mse'])
    return model

# %%
def fit_model(timeseries):
    length = len(timeseries)-1
    model = DC_CNN_Model(length)
    model.summary()
    X = timeseries[:-1].reshape(1,length, 1)
    y = timeseries[1:].reshape(1,length, 1)
    model.fit(X, y, epochs=3000, callbacks=[callback])
    return model
    
def forecast(model, timeseries, horizon: int):
    length = len(timeseries)-1
    pred_array = np.zeros(horizon).reshape(1, horizon, 1)
    X_test_initial = timeseries[1:].reshape(1,length,1)
    
    pred_array[: ,0, :] = model.predict(X_test_initial)[:, -1:, :]
    for i in range(horizon-1):
        pred_array[:, i+1:, :] = model.predict(
            np.append(
                X_test_initial[:, i+1:, :], 
                pred_array[:, :i+1, :]
            ).reshape(1, length, 1))[:, -1:, :]
    return pred_array.flatten()
    
def evaluate_timeseries(series, horizon: int):
    model = fit_model(series)
    pred_array = forecast(model, series, horizon)
    return pred_array, model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def show_result(y_test, predicted, ylabel="Passengers"):
  plt.figure(figsize=(16, 6))
  plt.plot(y_test.index, predicted, 'o-', label="predicted")
  plt.plot(y_test.index, y_test, '.-', label="actual")

  plt.ylabel(ylabel)
  plt.legend()

# %%
import pandas as pd

values = [         
  112., 118., 132., 129., 121., 135., 148., 148., 136., 119., 104., 118., 115., 126.,
  141., 135., 125., 149., 170., 170., 158., 133., 114., 140., 145., 150., 178., 163.,
  172., 178., 199., 199., 184., 162., 146., 166., 171., 180., 193., 181., 183., 218.,
  230., 242., 209., 191., 172., 194., 196., 196., 236., 235., 229., 243., 264., 272.,
  237., 211., 180., 201., 204., 188., 235., 227., 234., 264., 302., 293., 259., 229.,
  203., 229., 242., 233., 267., 269., 270., 315., 364., 347., 312., 274., 237., 278.,
  284., 277., 317., 313., 318., 374., 413., 405., 355., 306., 271., 306., 315., 301.,
  356., 348., 355., 422., 465., 467., 404., 347., 305., 336., 340., 318., 362., 348.,
  363., 435., 491., 505., 404., 359., 310., 337., 360., 342., 406., 396., 420., 472.,
  548., 559., 463., 407., 362., 405., 417., 391., 419., 461., 472., 535., 622., 606.,
  508., 461., 390., 432.,
 ]
idx = pd.date_range("1949-01-01", periods=len(values), freq="M")
passengers = pd.Series(values, index=idx, name="passengers").to_frame()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    passengers.passengers, passengers.passengers.shift(-1), shuffle=False
)
predictions, model = evaluate_timeseries(X_train.values.reshape(-1, 1), horizon=len(y_test))
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 107, 1)]     0
# __________________________________________________________________________________________________
# conv1d_223 (Conv1D)             (None, 107, 32)      64          input_14[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 107, 32)      0           conv1d_223[0][0]
# __________________________________________________________________________________________________
# conv1d_225 (Conv1D)             (None, 107, 1)       32          activation_80[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 107, 1)       0           input_14[0][0]
#                                                                  conv1d_225[0][0]
# __________________________________________________________________________________________________
# conv1d_226 (Conv1D)             (None, 107, 32)      64          add_80[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 107, 32)      0           conv1d_226[0][0]
# __________________________________________________________________________________________________
# conv1d_228 (Conv1D)             (None, 107, 1)       32          activation_81[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 107, 1)       0           add_80[0][0]
#                                                                  conv1d_228[0][0]
# __________________________________________________________________________________________________
# conv1d_229 (Conv1D)             (None, 107, 32)      64          add_81[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 107, 32)      0           conv1d_229[0][0]
# __________________________________________________________________________________________________
# conv1d_231 (Conv1D)             (None, 107, 1)       32          activation_82[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 107, 1)       0           add_81[0][0]
#                                                                  conv1d_231[0][0]
# __________________________________________________________________________________________________
# conv1d_232 (Conv1D)             (None, 107, 32)      64          add_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 107, 32)      0           conv1d_232[0][0]
# __________________________________________________________________________________________________
# conv1d_234 (Conv1D)             (None, 107, 1)       32          activation_83[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 107, 1)       0           add_82[0][0]
#                                                                  conv1d_234[0][0]
# __________________________________________________________________________________________________
# conv1d_235 (Conv1D)             (None, 107, 32)      64          add_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 107, 32)      0           conv1d_235[0][0]
# __________________________________________________________________________________________________
# conv1d_237 (Conv1D)             (None, 107, 1)       32          activation_84[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 107, 1)       0           add_83[0][0]
#                                                                  conv1d_237[0][0]
# __________________________________________________________________________________________________
# conv1d_238 (Conv1D)             (None, 107, 32)      64          add_84[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 107, 32)      0           conv1d_238[0][0]
# __________________________________________________________________________________________________
# conv1d_240 (Conv1D)             (None, 107, 1)       32          activation_85[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 107, 1)       0           add_84[0][0]
#                                                                  conv1d_240[0][0]
# __________________________________________________________________________________________________
# conv1d_241 (Conv1D)             (None, 107, 32)      64          add_85[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 107, 32)      0           conv1d_241[0][0]
# __________________________________________________________________________________________________
# conv1d_239 (Conv1D)             (None, 107, 1)       32          activation_85[0][0]
# __________________________________________________________________________________________________
# conv1d_242 (Conv1D)             (None, 107, 1)       32          activation_86[0][0]
# __________________________________________________________________________________________________
# conv1d_224 (Conv1D)             (None, 107, 1)       32          activation_80[0][0]
# __________________________________________________________________________________________________
# conv1d_227 (Conv1D)             (None, 107, 1)       32          activation_81[0][0]
# __________________________________________________________________________________________________
# conv1d_230 (Conv1D)             (None, 107, 1)       32          activation_82[0][0]
# __________________________________________________________________________________________________
# conv1d_233 (Conv1D)             (None, 107, 1)       32          activation_83[0][0]
# __________________________________________________________________________________________________
# conv1d_236 (Conv1D)             (None, 107, 1)       32          activation_84[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 107, 1)       0           conv1d_239[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 107, 1)       0           conv1d_242[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 107, 1)       0           conv1d_224[0][0]
#                                                                  conv1d_227[0][0]
#                                                                  conv1d_230[0][0]
#                                                                  conv1d_233[0][0]
#                                                                  conv1d_236[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 107, 1)       0           add_87[0][0]
# __________________________________________________________________________________________________
# conv1d_244 (Conv1D)             (None, 107, 1)       1           activation_87[0][0]
# ==================================================================================================
# Total params: 865
# Trainable params: 865
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/3000
# 1/1 [==============================] - 5s 5s/step - loss: 105.8484 - mse: 18958.8438
# Epoch 2/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 97.2172 - mse: 17626.3789
# Epoch 3/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 82.9756 - mse: 14388.8789
# Epoch 4/3000
# 1/1 [==============================] - 0s 11ms/step - loss: 81.5022 - mse: 14346.2695
# Epoch 5/3000
# 1/1 [==============================] - 0s 23ms/step - loss: 69.8558 - mse: 11267.2080
# Epoch 6/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 88.1358 - mse: 16948.1289
# Epoch 7/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 73.1774 - mse: 14335.2510
# Epoch 8/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 56.3049 - mse: 8766.3496
# Epoch 9/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 79.0379 - mse: 15396.3271
# Epoch 10/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 63.3655 - mse: 10556.6016
# Epoch 11/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 55.4056 - mse: 7999.2124
# Epoch 12/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 58.2993 - mse: 8548.5293
# Epoch 13/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 46.3683 - mse: 5224.5259
# Epoch 14/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 43.8162 - mse: 4830.6064
# Epoch 15/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 49.2297 - mse: 5822.2588
# Epoch 16/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 41.7001 - mse: 4011.4082
# Epoch 17/3000
# 1/1 [==============================] - 0s 16ms/step - loss: 38.4574 - mse: 3840.1960
# Epoch 18/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 31.6833 - mse: 2150.6946
# Epoch 19/3000
# 1/1 [==============================] - 0s 14ms/step - loss: 28.4091 - mse: 1634.8049
# Epoch 20/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 28.5797 - mse: 1558.0737
# Epoch 21/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 28.6146 - mse: 1658.5842
# Epoch 22/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 28.1060 - mse: 1469.7397
# Epoch 23/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 28.9485 - mse: 1597.7910
# Epoch 24/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 24.7484 - mse: 1139.7495
# Epoch 25/3000
# 1/1 [==============================] - 0s 17ms/step - loss: 21.7753 - mse: 858.8422
# Epoch 26/3000
# 1/1 [==============================] - 0s 12ms/step - loss: 22.1664 - mse: 859.6282
# Epoch 27/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 21.8630 - mse: 824.5412
# Epoch 28/3000
# 1/1 [==============================] - 0s 13ms/step - loss: 23.0833 - mse: 1009.9910
# Epoch 29/3000
# 1/1 [==============================] - 0s 22ms/step - loss: 23.1247 - mse: 951.9030
# Epoch 30/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 22.5393 - mse: 919.4270
# Epoch 31/3000
# 1/1 [==============================] - 0s 12ms/step - loss: 21.7842 - mse: 822.9183
# Epoch 32/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 21.8658 - mse: 795.7057
# Epoch 33/3000
# 1/1 [==============================] - 0s 12ms/step - loss: 22.6554 - mse: 876.9241
# Epoch 34/3000
# 1/1 [==============================] - 0s 11ms/step - loss: 21.7525 - mse: 826.6436
# Epoch 35/3000
# 1/1 [==============================] - 0s 26ms/step - loss: 21.1963 - mse: 815.2258
# Epoch 36/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 20.6331 - mse: 735.6699
# Epoch 37/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 20.9443 - mse: 767.3633
# Epoch 38/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 20.4509 - mse: 777.8323
# Epoch 39/3000
# 1/1 [==============================] - 0s 13ms/step - loss: 20.9826 - mse: 791.9006
# Epoch 40/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 20.8335 - mse: 748.8900
# Epoch 41/3000
# 1/1 [==============================] - 0s 16ms/step - loss: 20.2972 - mse: 717.2205
# Epoch 42/3000
# 1/1 [==============================] - 0s 12ms/step - loss: 20.9647 - mse: 755.4875
# Epoch 43/3000
# 1/1 [==============================] - 0s 17ms/step - loss: 20.7845 - mse: 758.4638
# Epoch 44/3000
# 1/1 [==============================] - 0s 15ms/step - loss: 20.0289 - mse: 693.4433
# Epoch 45/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 20.0784 - mse: 712.4917
# Epoch 46/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 20.3375 - mse: 717.1219
# Epoch 47/3000
# 1/1 [==============================] - 0s 18ms/step - loss: 20.0042 - mse: 670.3476
# Epoch 48/3000
# 1/1 [==============================] - 0s 36ms/step - loss: 20.8315 - mse: 745.1225
# Epoch 49/3000
# 1/1 [==============================] - 0s 21ms/step - loss: 20.4175 - mse: 715.6703
# Epoch 50/3000
# 1/1 [==============================] - 0s 19ms/step - loss: 20.1455 - mse: 687.6291
# Epoch 51/3000
# 1/1 [==============================] - 0s 12ms/step - loss: 20.8171 - mse: 720.9146
# Epoch 52/3000
# 1/1 [==============================] - 0s 14ms/step - loss: 18.7657 - mse: 618.3374
# Epoch 53/3000
# 1/1 [==============================] - 0s 14ms/step - loss: 20.2889 - mse: 672.0312
# Epoch 54/3000
# 1/1 [==============================] - 0s 16ms/step - loss: 19.8908 - mse: 665.2711
# Epoch 55/3000
# 1/1 [==============================] - 0s 12ms/step - loss: 20.7446 - mse: 733.8403
# Epoch 56/3000
# 1/1 [==============================] - 0s 12ms/step - loss: 19.5899 - mse: 642.9553
# Epoch 57/3000
# 1/1 [==============================] - 0s 13ms/step - loss: 20.2158 - mse: 710.8728
# Epoch 58/3000
# 1/1 [==============================] - 0s 12ms/step - loss: 19.2186 - mse: 617.6512
# Epoch 59/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 19.9735 - mse: 662.5042
# Epoch 60/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 19.4917 - mse: 658.0519
# Epoch 61/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 19.1305 - mse: 635.3354
# Epoch 62/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 19.7467 - mse: 656.5818

# %%
show_result(y_test[:HORIZON], predictions[:HORIZON], "Passengers")
