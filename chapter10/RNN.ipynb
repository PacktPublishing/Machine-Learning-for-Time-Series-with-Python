# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)

# %%
import pandas as pd

values = [         
  112., 118., 132., 129., 121., 135., 148., 148., 136., 119., 104., 118., 115., 126.,
  141., 135., 125., 149., 170., 170., 158., 133., 114., 140., 145., 150., 178., 163.,
  172., 178., 199., 199., 184., 162., 146., 166., 171., 180., 193., 181., 183., 218.,
  230., 242., 209., 191., 172., 194., 196., 196., 236., 235., 229., 243., 264., 272.,
  237., 211., 180., 201., 204., 188., 235., 227., 234., 264., 302., 293., 259., 229.,
  203., 229., 242., 233., 267., 269., 270., 315., 364., 347., 312., 274., 237., 278.,
  284., 277., 317., 313., 318., 374., 413., 405., 355., 306., 271., 306., 315., 301.,
  356., 348., 355., 422., 465., 467., 404., 347., 305., 336., 340., 318., 362., 348.,
  363., 435., 491., 505., 404., 359., 310., 337., 360., 342., 406., 396., 420., 472.,
  548., 559., 463., 407., 362., 405., 417., 391., 419., 461., 472., 535., 622., 606.,
  508., 461., 390., 432.,
 ]
idx = pd.date_range("1949-01-01", periods=len(values), freq="M")
passengers = pd.Series(values, index=idx, name="passengers").to_frame()

# %%
passengers
# Out:
#             passengers
# 1949-01-31       112.0
# 1949-02-28       118.0
# 1949-03-31       132.0
# 1949-04-30       129.0
# 1949-05-31       121.0
# ...                ...
# 1960-08-31       606.0
# 1960-09-30       508.0
# 1960-10-31       461.0
# 1960-11-30       390.0
# 1960-12-31       432.0
#
# [144 rows x 1 columns]

# %%
LOOKBACK = 10

def wrap_data(df, lookback):
  dataset = []
  for index in range(lookback, len(df)+1):
    features = {
        f"col_{i}": float(val) for i, val in enumerate(
          df.iloc[index-lookback:index].values
        )
    }
    row = pd.DataFrame.from_dict([features])
    row.index = [df.index[index-1]]
    dataset.append(row)
  return pd.concat(dataset, axis=0)

dataset = wrap_data(passengers, lookback=LOOKBACK)
dataset = dataset.join(passengers.shift(-1))

# %%
import tensorflow.keras as keras
from tensorflow.keras.layers import Input, Bidirectional, LSTM, Dense
import tensorflow as tf

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

def create_model(passengers):
  input_layer = Input(shape=(LOOKBACK, 1))
  recurrent = Bidirectional(LSTM(20, activation="relu"))(input_layer)
  output_layer = Dense(1)(recurrent)
  model = keras.models.Model(inputs=input_layer, outputs=output_layer)
  model.compile(loss='mse', optimizer=keras.optimizers.Adagrad(),
    metrics=[keras.metrics.RootMeanSquaredError(), keras.metrics.MeanAbsoluteError()])
  return model

model = create_model(passengers)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    dataset.drop(columns="passengers"),
    dataset["passengers"],
    shuffle=False
)

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[callback])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 2s 9ms/step - loss: 52732.9688 - root_mean_squared_error: 229.6366 - mean_absolute_error: 197.0877
# Epoch 2/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 33408.8945 - root_mean_squared_error: 182.7810 - mean_absolute_error: 141.7884
# Epoch 3/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 29006.7559 - root_mean_squared_error: 170.3137 - mean_absolute_error: 124.8090
# Epoch 4/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 23936.4883 - root_mean_squared_error: 154.7142 - mean_absolute_error: 111.0472
# Epoch 5/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 22389.9707 - root_mean_squared_error: 149.6328 - mean_absolute_error: 104.0923
# Epoch 6/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 18862.2695 - root_mean_squared_error: 137.3400 - mean_absolute_error: 95.1812
# Epoch 7/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 15780.9756 - root_mean_squared_error: 125.6224 - mean_absolute_error: 82.8671
# Epoch 8/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14400.4453 - root_mean_squared_error: 120.0019 - mean_absolute_error: 77.3706
# Epoch 9/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 12252.4521 - root_mean_squared_error: 110.6908 - mean_absolute_error: 68.8472
# Epoch 10/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 13337.9023 - root_mean_squared_error: 115.4898 - mean_absolute_error: 74.1866
# Epoch 11/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 13267.1172 - root_mean_squared_error: 115.1830 - mean_absolute_error: 72.8856
# Epoch 12/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12184.6221 - root_mean_squared_error: 110.3840 - mean_absolute_error: 67.6589
# Epoch 13/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 6349.4390 - root_mean_squared_error: 79.6834 - mean_absolute_error: 51.6397
# Epoch 14/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 2623.2092 - root_mean_squared_error: 51.2173 - mean_absolute_error: 38.4974
# Epoch 15/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2580.8042 - root_mean_squared_error: 50.8016 - mean_absolute_error: 37.7732
# Epoch 16/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 2738.7886 - root_mean_squared_error: 52.3334 - mean_absolute_error: 36.6078
# Epoch 17/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1857.8059 - root_mean_squared_error: 43.1023 - mean_absolute_error: 31.6434
# Epoch 18/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1968.2155 - root_mean_squared_error: 44.3646 - mean_absolute_error: 32.3682
# Epoch 19/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 1823.0355 - root_mean_squared_error: 42.6970 - mean_absolute_error: 31.3262
# Epoch 20/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 1784.0868 - root_mean_squared_error: 42.2385 - mean_absolute_error: 30.9401
# Epoch 21/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 1839.0665 - root_mean_squared_error: 42.8843 - mean_absolute_error: 31.2791
# Epoch 22/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1791.3098 - root_mean_squared_error: 42.3239 - mean_absolute_error: 31.3115
# Epoch 23/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1746.6917 - root_mean_squared_error: 41.7934 - mean_absolute_error: 31.3603
# Epoch 24/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1705.4607 - root_mean_squared_error: 41.2972 - mean_absolute_error: 31.0609
# Epoch 25/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 1685.0898 - root_mean_squared_error: 41.0498 - mean_absolute_error: 30.9557
# Epoch 26/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1671.0116 - root_mean_squared_error: 40.8780 - mean_absolute_error: 30.7351
# Epoch 27/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1637.9150 - root_mean_squared_error: 40.4712 - mean_absolute_error: 30.8134
# Epoch 28/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 1615.2218 - root_mean_squared_error: 40.1898 - mean_absolute_error: 30.5465
# Epoch 29/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1527.3145 - root_mean_squared_error: 39.0809 - mean_absolute_error: 29.9376
# Epoch 30/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1517.1260 - root_mean_squared_error: 38.9503 - mean_absolute_error: 29.8537
# Epoch 31/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 1514.3906 - root_mean_squared_error: 38.9152 - mean_absolute_error: 29.8186
# Epoch 32/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1507.7211 - root_mean_squared_error: 38.8294 - mean_absolute_error: 29.7300
# Epoch 33/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1501.3844 - root_mean_squared_error: 38.7477 - mean_absolute_error: 29.6400
# Epoch 34/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1496.3732 - root_mean_squared_error: 38.6830 - mean_absolute_error: 29.4767
# Epoch 35/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1493.6239 - root_mean_squared_error: 38.6474 - mean_absolute_error: 29.4815
# Epoch 36/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1490.6760 - root_mean_squared_error: 38.6093 - mean_absolute_error: 29.5494
# Epoch 37/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 1484.9049 - root_mean_squared_error: 38.5345 - mean_absolute_error: 29.5329
# Epoch 38/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1478.7859 - root_mean_squared_error: 38.4550 - mean_absolute_error: 29.3956
# Epoch 39/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1484.8130 - root_mean_squared_error: 38.5333 - mean_absolute_error: 29.4792
# Epoch 40/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 1500.1581 - root_mean_squared_error: 38.7319 - mean_absolute_error: 29.7902
# Epoch 41/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1471.8428 - root_mean_squared_error: 38.3646 - mean_absolute_error: 29.4151
# Epoch 42/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 1464.3508 - root_mean_squared_error: 38.2668 - mean_absolute_error: 29.3819
# Epoch 43/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 1467.1071 - root_mean_squared_error: 38.3028 - mean_absolute_error: 29.4470
# Epoch 44/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1455.6951 - root_mean_squared_error: 38.1536 - mean_absolute_error: 29.2951
# Epoch 45/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1450.7053 - root_mean_squared_error: 38.0881 - mean_absolute_error: 29.3543
# Epoch 46/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1566.5057 - root_mean_squared_error: 39.5791 - mean_absolute_error: 30.8404
# Epoch 47/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 1473.6260 - root_mean_squared_error: 38.3878 - mean_absolute_error: 29.9741
# Epoch 48/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1475.4691 - root_mean_squared_error: 38.4118 - mean_absolute_error: 30.1618

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def show_result(y_test, predicted):
  plt.figure(figsize=(16, 6))
  plt.plot(y_test.index, predicted, 'o-', label="predicted")
  plt.plot(y_test.index, y_test, '.-', label="actual")

  plt.ylabel("Passengers")
  plt.legend()

# %%
predicted = model.predict(X_test)
show_result(y_test, predicted)
